# %%
import pandas as pd

# %%
# Load the CSVs for different percentages (if available)
path_katun_hitam = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_results\katun_htm_glcm_result.csv"
path_katun_putih = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_results\katun_pth_glcm_result.csv"
path_polyester_hitam = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_results\polyester_htm_glcm_result.csv"
path_polyester_putih = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_results\polyester_pth_glcm_result.csv"

# Reading the data assuming they follow the same structure
df_kh = pd.read_csv(path_katun_hitam)
df_kp = pd.read_csv(path_katun_putih)
df_ph = pd.read_csv(path_polyester_hitam)
df_pp = pd.read_csv(path_polyester_putih)

# %%
df_kh.describe()
# Out:
#           mean_R     mean_G     mean_B  contrast_R  dissimilarity_R  \
# count  25.000000  25.000000  25.000000   25.000000        25.000000
# mean   63.459156  73.925896  84.518829    0.813832         0.544753
# std     0.301573   0.326933   0.337623    0.032055         0.013252
# min    62.907298  73.435570  84.154570    0.720225         0.504845
# 25%    63.263058  73.768185  84.264237    0.800435         0.539758
# 50%    63.355055  73.803327  84.319658    0.819541         0.547483
# 75%    63.591684  73.854427  84.787268    0.841813         0.556159
# max    64.065070  74.703050  85.233456    0.856083         0.561792
#
#        homogeneity_R   energy_R  correlation_R      asm_R  entropy_R  ...  \
# count      25.000000  25.000000      25.000000  25.000000  25.000000  ...
# mean        0.753465   0.268451       0.826412   0.072317  17.497116  ...
# std         0.004878   0.003480       0.003608   0.001885   0.155164  ...
# ...

# %%
df_kh
# Out:
#      filename     mean_R     mean_G     mean_B  contrast_R  dissimilarity_R  \
# 0   kh_01.jpg  62.907298  73.435570  84.388401    0.845958         0.557523
# 1   kh_02.jpg  63.244391  73.770731  84.727679    0.856083         0.561792
# 2   kh_03.jpg  63.308859  73.854427  84.325872    0.813242         0.544382
# 3   kh_04.jpg  63.323322  73.837535  84.304525    0.720225         0.504845
# 4   kh_05.jpg  63.225118  73.804765  84.280614    0.763612         0.524304
# 5   kh_06.jpg  63.267244  73.771090  84.217467    0.772415         0.527730
# 6   kh_07.jpg  63.229412  73.797044  84.285510    0.827405         0.550338
# 7   kh_08.jpg  63.790106  74.411669  84.945560    0.845186         0.557742
# 8   kh_09.jpg  63.987816  74.576431  85.100700    0.844534         0.557333
# 9   kh_10.jpg  64.065070  74.703050  85.233456    0.788119         0.534514
# 10  kh_11.jpg  63.972285  74.562799  85.073321    0.785916         0.533616
# ...

# %%
def process_dataframe(df):
    """Drop non-numeric columns and compute the mean of the remaining columns."""
    df_numeric = df.drop(columns=['filename'])  # Menghapus kolom 'filename' jika ada
    return df_numeric.mean()  # Mengembalikan rata-rata setiap kolom fitur

# Proses semua dataframe kain
mean_kh = process_dataframe(df_kh)  # Katun Hitam
mean_kp = process_dataframe(df_kp)  # Katun Putih
mean_ph = process_dataframe(df_ph)  # Polyester Hitam
mean_pp = process_dataframe(df_pp)  # Polyester Putih

# Gabungkan semua rata-rata ke dalam satu dataframe
mean_df = pd.DataFrame({
    'Katun Hitam': mean_kh,
    'Katun Putih': mean_kp,
    'Polyester Hitam': mean_ph,
    'Polyester Putih': mean_pp
})

mean_df
# Out:
#                  Katun Hitam  Katun Putih  Polyester Hitam  Polyester Putih
# mean_R             63.459156   150.761029        57.478453       155.349279
# mean_G             73.925896   167.005546        63.883607       170.783558
# mean_B             84.518829   181.015702        71.215896       185.316931
# contrast_R          0.813832     0.072067         2.494730         0.045275
# dissimilarity_R     0.544753     0.071538         0.874998         0.044925
# homogeneity_R       0.753465     0.964284         0.684802         0.977572
# energy_R            0.268451     0.432960         0.225377         0.644066
# correlation_R       0.826412     0.980936         0.806200         0.939957
# asm_R               0.072317     0.187496         0.051001         0.414889
# entropy_R          17.497116    11.289563        21.072249         6.418002
# contrast_G          0.815271     0.072292         2.526833         0.045946
# ...

# %%
# Fungsi untuk mengambil standar deviasi dari setiap fitur numerik
def process_dataframe2(df):
    """Drop non-numeric columns and compute the standard deviation of the remaining columns."""
    df_numeric = df.drop(columns=['filename'])  # Menghapus kolom non-numerik
    return df_numeric.std()  # Mengembalikan standar deviasi tiap kolom

# Proses semua dataframe kain
std_kh = process_dataframe2(df_kh)  # Katun Hitam
std_kp = process_dataframe2(df_kp)  # Katun Putih
std_ph = process_dataframe2(df_ph)  # Polyester Hitam
std_pp = process_dataframe2(df_pp)  # Polyester Putih

# Gabungkan semua standar deviasi ke dalam satu dataframe
std_df = pd.DataFrame({
    'Katun Hitam': std_kh,
    'Katun Putih': std_kp,
    'Polyester Hitam': std_ph,
    'Polyester Putih': std_pp
})

std_df
# Out:
#                  Katun Hitam  Katun Putih  Polyester Hitam  Polyester Putih
# mean_R              0.301573     1.579261         0.597646         0.376448
# mean_G              0.326933     1.514563         0.468547         0.356389
# mean_B              0.337623     1.573220         0.692579         0.390735
# contrast_R          0.032055     0.001732         0.064937         0.002089
# dissimilarity_R     0.013252     0.001683         0.012995         0.002078
# homogeneity_R       0.004878     0.000836         0.003002         0.001038
# energy_R            0.003480     0.001810         0.001437         0.006447
# correlation_R       0.003608     0.001087         0.003249         0.001258
# asm_R               0.001885     0.001571         0.000649         0.008277
# entropy_R           0.155164     0.096390         0.077276         0.111315
# contrast_G          0.032080     0.001711         0.065947         0.002275
# ...

# %%
mean_df.to_csv(r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_results\mean_glcm_results.csv")  # Save the combined dataframe to a CSV file

# %%
import os
# Tentukan folder tempat menyimpan gambar
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"  # Ganti dengan path folder tujuan

# Buat folder jika belum ada
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the top-level categories (jenis kain) dan channel warna
fabrics_black = ['Katun Hitam', 'Polyester Hitam']
fabrics_white = ['Katun Putih', 'Polyester Putih']
channels = ['Blue', 'Green', 'Red']

# The number of channels per concentration level
n_channels = len(channels)

# Offset untuk setiap kelompok bar
offset = 0.2

# Flatten the x-axis labels to create a list of repeated color channels under each concentration
x_labels_black = [f"{channel}" for _ in fabrics_black for channel in channels]
x_labels_white = [f"{channel}" for _ in fabrics_white for channel in channels]

# Create tick positions for both levels
tick_positions_black = np.arange(len(x_labels_black))
tick_positions_white = np.arange(len(x_labels_white))

# Extract the feature data for each color channel and percentage
contrast_blue = mean_df.loc['contrast_B']
contrast_green = mean_df.loc['contrast_G']
contrast_red = mean_df.loc['contrast_R']

homogeneity_blue = mean_df.loc['homogeneity_B']
homogeneity_green = mean_df.loc['homogeneity_G']
homogeneity_red = mean_df.loc['homogeneity_R']

disimilarity_blue = mean_df.loc['dissimilarity_B']
disimilarity_green = mean_df.loc['dissimilarity_G']
disimilarity_red = mean_df.loc['dissimilarity_R']

energy_blue = mean_df.loc['energy_B']
energy_green = mean_df.loc['energy_G']
energy_red = mean_df.loc['energy_R']

correlation_blue = mean_df.loc['correlation_B']
correlation_green = mean_df.loc['correlation_G']
correlation_red = mean_df.loc['correlation_R']

entropy_blue = mean_df.loc['entropy_B']
entropy_green = mean_df.loc['entropy_G']
entropy_red = mean_df.loc['entropy_R']

asm_blue = mean_df.loc['asm_B']
asm_green = mean_df.loc['asm_G']
asm_red = mean_df.loc['asm_R']


# Filter data berdasarkan jenis kain (hitam dan putih)
contrast_black = [
    contrast_blue[0], contrast_green[0], contrast_red[0],  # Katun Hitam
    contrast_blue[2], contrast_green[2], contrast_red[2]   # Polyester Hitam
]

contrast_white = [
    contrast_blue[1], contrast_green[1], contrast_red[1],  # Katun Putih
    contrast_blue[3], contrast_green[3], contrast_red[3]   # Polyester Putih
]

homogeneity_black = [
    homogeneity_blue[0], homogeneity_green[0], homogeneity_red[0],  # Katun Hitam
    homogeneity_blue[2], homogeneity_green[2], homogeneity_red[2]   # Polyester Hitam
]

homogeneity_white = [
    homogeneity_blue[1], homogeneity_green[1], homogeneity_red[1],  # Katun Putih
    homogeneity_blue[3], homogeneity_green[3], homogeneity_red[3]   # Polyester Putih
]

disimilarity_black = [
    disimilarity_blue[0], disimilarity_green[0], disimilarity_red[0],  # Katun Hitam
    disimilarity_blue[2], disimilarity_green[2], disimilarity_red[2]   # Polyester Hitam
]

disimilarity_white = [
    disimilarity_blue[1], disimilarity_green[1], disimilarity_red[1],  # Katun Putih
    disimilarity_blue[3], disimilarity_green[3], disimilarity_red[3]   # Polyester Putih
]

energy_black = [
    energy_blue[0], energy_green[0], energy_red[0],  # Katun Hitam
    energy_blue[2], energy_green[2], energy_red[2]   # Polyester Hitam
]

energy_white = [
    energy_blue[1], energy_green[1], energy_red[1],  # Katun Putih
    energy_blue[3], energy_green[3], energy_red[3]   # Polyester Putih
]

correlation_black = [
    correlation_blue[0], correlation_green[0], correlation_red[0],  # Katun Hitam
    correlation_blue[2], correlation_green[2], correlation_red[2]   # Polyester Hitam
]

correlation_white = [
    correlation_blue[1], correlation_green[1], correlation_red[1],  # Katun Putih
    correlation_blue[3], correlation_green[3], correlation_red[3]   # Polyester Putih
]

entropy_black = [
    entropy_blue[0], entropy_green[0], entropy_red[0],  # Katun Hitam
    entropy_blue[2], entropy_green[2], entropy_red[2]   # Polyester Hitam
]

entropy_white = [
    entropy_blue[1], entropy_green[1], entropy_red[1],  # Katun Putih
    entropy_blue[3], entropy_green[3], entropy_red[3]   # Polyester Putih
]

asm_black = [
    asm_blue[0], asm_green[0], asm_red[0],  # Katun Hitam
    asm_blue[2], asm_green[2], asm_red[2]   # Polyester Hitam
]

asm_white = [
    asm_blue[1], asm_green[1], asm_red[1],  # Katun Putih
    asm_blue[3], asm_green[3], asm_red[3]   # Polyester Putih
]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_4632\3326561698.py:55: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[0], contrast_green[0], contrast_red[0],  # Katun Hitam
# C:\Users\asus\AppData\Local\Temp\ipykernel_4632\3326561698.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[2], contrast_green[2], contrast_red[2]   # Polyester Hitam
# ...

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Fungsi untuk membuat plot
def create_contrast_plot(fabrics, x_labels, tick_positions, contrast_data, title, output_path):
    # Membuat figure dengan ukuran yang lebih besar
    plt.figure(figsize=(14, 6))
    
    # Menggambar garis dan marker
    plt.plot(tick_positions, contrast_data, label='Contrast', marker='o', markersize=8, color='blue')
    
    # Menambahkan grid dengan opasitas rendah
    plt.grid(True, linestyle='--', alpha=0.6)
    
    # Menambahkan judul dan label sumbu
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel('Average Values', fontsize=12)
    plt.xticks(tick_positions, x_labels, rotation=0, fontsize=10)
    
    # Tambahkan label jenis kain di tengah setiap grup RGB
    for i, fabric in enumerate(fabrics):
        plt.text(i * n_channels + 1, plt.ylim()[1] - 0.0001, fabric, ha='center', va='top', fontsize=12, fontweight='bold')
    
    # Tambahkan garis pemisah antar jenis kain
    for i in range(1, len(fabrics)):
        plt.axvline(x=i * n_channels - 0.5, color='black', linestyle='--', lw=1)
    
    # Menambahkan legenda dengan posisi yang lebih baik
    plt.legend(loc='upper right', fontsize=10)
    
    # Mengatur layout agar elemen-elemen tidak saling tumpang tindih
    plt.tight_layout()
    
    # Simpan plot ke dalam file
    plt.savefig(output_path, dpi=400)
    
    # Tampilkan plot
    plt.show()

# Define folder output (pastikan folder sudah ada)
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"

# Plot untuk kain warna hitam
file_name_black = "contrast_jenis_kain_hitam.png"
output_path_black = os.path.join(output_folder, file_name_black)
create_contrast_plot(
    fabrics_black,
    x_labels_black,
    tick_positions_black,
    contrast_black,
    "Contrast pada Jenis Kain Warna Hitam di Setiap Channel RGB",
    output_path_black
)

# Plot untuk kain warna putih
file_name_white = "contrast_jenis_kain_putih.png"
output_path_white = os.path.join(output_folder, file_name_white)
create_contrast_plot(
    fabrics_white,
    x_labels_white,
    tick_positions_white,
    contrast_white,
    "Contrast pada Jenis Kain Warna Putih di Setiap Channel RGB",
    output_path_white
)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Fungsi reusable untuk membuat plot
def create_homogeneity_plot(fabrics, x_labels, tick_positions, homogeneity_data, title, output_path):
    plt.figure(figsize=(14, 6))
    plt.plot(tick_positions, homogeneity_data, label='Homogeneity', marker='s', markersize=8, color='green')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel('Average Values', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(tick_positions, x_labels, rotation=0, fontsize=10)

    # Tambahkan label jenis kain di tengah setiap grup RGB
    for i, fabric in enumerate(fabrics):
        plt.text(i * n_channels + 1, plt.ylim()[1] - 0.0003, fabric, ha='center', va='top', fontsize=12, fontweight='bold')

    # Tambahkan garis pemisah antar jenis kain
    for i in range(1, len(fabrics)):
        plt.axvline(x=i * n_channels - 0.5, color='gray', linestyle='--', lw=1)

    plt.legend(loc='upper right', fontsize=10)
    plt.tight_layout()

    # Simpan plot ke dalam file
    plt.savefig(output_path, dpi=400)
    plt.show()


# Folder output
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"

# Plot untuk kain warna hitam
file_name_black = "homogeneity_jenis_kain_hitam.png"
output_path_black = os.path.join(output_folder, file_name_black)
create_homogeneity_plot(
    fabrics_black,
    x_labels_black,
    tick_positions_black,
    homogeneity_black,
    "Homogeneity pada Jenis Kain Warna Hitam di Setiap Channel RGB",
    output_path_black
)

# Plot untuk kain warna putih
file_name_white = "homogeneity_jenis_kain_putih.png"
output_path_white = os.path.join(output_folder, file_name_white)
create_homogeneity_plot(
    fabrics_white,
    x_labels_white,
    tick_positions_white,
    homogeneity_white,
    "Homogeneity pada Jenis Kain Warna Putih di Setiap Channel RGB",
    output_path_white
)

# %%
# Fungsi reusable untuk membuat plot
def create_dissimilarity_plot(fabrics, x_labels, tick_positions, dissimilarity_data, title, output_path):
    plt.figure(figsize=(14, 6))
    plt.plot(tick_positions, dissimilarity_data, label='Dissimilarity', marker='^', markersize=8, color='red')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel('Average Values', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(tick_positions, x_labels, rotation=0, fontsize=10)

    # Tambahkan label jenis kain di tengah setiap grup RGB
    for i, fabric in enumerate(fabrics):
        plt.text(i * n_channels + 1, plt.ylim()[1] - 0.0002, fabric, ha='center', va='top', fontsize=12, fontweight='bold')

    # Tambahkan garis pemisah antar jenis kain
    for i in range(1, len(fabrics)):
        plt.axvline(x=i * n_channels - 0.5, color='gray', linestyle='--', lw=1)

    plt.legend(loc='upper right', fontsize=10)
    plt.tight_layout()

    # Simpan plot ke dalam file
    plt.savefig(output_path, dpi=400)
    plt.show()


# Folder output
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"

# Plot untuk kain warna hitam
file_name_black = "dissimilarity_jenis_kain_hitam.png"
output_path_black = os.path.join(output_folder, file_name_black)
create_dissimilarity_plot(
    fabrics_black,
    x_labels_black,
    tick_positions_black,
    disimilarity_black,
    "Dissimilarity pada Jenis Kain Warna Hitam di Setiap Channel RGB",
    output_path_black
)

# Plot untuk kain warna putih
file_name_white = "dissimilarity_jenis_kain_putih.png"
output_path_white = os.path.join(output_folder, file_name_white)
create_dissimilarity_plot(
    fabrics_white,
    x_labels_white,
    tick_positions_white,
    disimilarity_white,
    "Dissimilarity pada Jenis Kain Warna Putih di Setiap Channel RGB",
    output_path_white
)

# %%
# Fungsi reusable untuk membuat plot
def create_correlation_plot(fabrics, x_labels, tick_positions, correlation_data, title, output_path):
    plt.figure(figsize=(14, 6))
    plt.plot(tick_positions, correlation_data, label='Correlation', marker='*', markersize=8, color='purple')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel('Average Values', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(tick_positions, x_labels, rotation=0, fontsize=10)

    # Tambahkan label jenis kain di tengah setiap grup RGB
    for i, fabric in enumerate(fabrics):
        plt.text(i * n_channels + 1, plt.ylim()[1] - 0.0005, fabric, ha='center', va='top', fontsize=12, fontweight='bold')

    # Tambahkan garis pemisah antar jenis kain
    for i in range(1, len(fabrics)):
        plt.axvline(x=i * n_channels - 0.5, color='gray', linestyle='--', lw=1)

    plt.legend(loc='upper right', fontsize=10)
    plt.tight_layout()

    # Simpan plot ke dalam file
    plt.savefig(output_path, dpi=400)
    plt.show()


# Folder output
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"

# Plot untuk kain warna hitam
file_name_black = "correlation_jenis_kain_hitam.png"
output_path_black = os.path.join(output_folder, file_name_black)
create_correlation_plot(
    fabrics_black,
    x_labels_black,
    tick_positions_black,
    correlation_black,
    "Correlation pada Jenis Kain Warna Hitam di Setiap Channel RGB",
    output_path_black
)

# Plot untuk kain warna putih
file_name_white = "correlation_jenis_kain_putih.png"
output_path_white = os.path.join(output_folder, file_name_white)
create_correlation_plot(
    fabrics_white,
    x_labels_white,
    tick_positions_white,
    correlation_white,
    "Correlation pada Jenis Kain Warna Putih di Setiap Channel RGB",
    output_path_white
)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Fungsi reusable untuk membuat plot
def create_energy_plot(fabrics, x_labels, tick_positions, energy_data, title, output_path):
    plt.figure(figsize=(14, 6))
    plt.plot(tick_positions, energy_data, label='Energy', marker='d', markersize=8, color='orange')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel('Average Values', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(tick_positions, x_labels, rotation=0, fontsize=10)

    # Tambahkan label jenis kain di tengah setiap grup RGB
    for i, fabric in enumerate(fabrics):
        plt.text(i * n_channels + 1, plt.ylim()[1] - 0.0005, fabric, ha='center', va='top', fontsize=12, fontweight='bold')

    # Tambahkan garis pemisah antar jenis kain
    for i in range(1, len(fabrics)):
        plt.axvline(x=i * n_channels - 0.5, color='gray', linestyle='--', lw=1)

    plt.legend(loc='upper right', fontsize=10)
    plt.tight_layout()

    # Simpan plot ke dalam file
    plt.savefig(output_path, dpi=400)
    plt.show()


# Folder output
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"

# Plot untuk kain warna hitam
file_name_black = "energy_jenis_kain_hitam.png"
output_path_black = os.path.join(output_folder, file_name_black)
create_energy_plot(
    fabrics_black,
    x_labels_black,
    tick_positions_black,
    energy_black,
    "Energy pada Jenis Kain Warna Hitam di Setiap Channel RGB",
    output_path_black
)

# Plot untuk kain warna putih
file_name_white = "energy_jenis_kain_putih.png"
output_path_white = os.path.join(output_folder, file_name_white)
create_energy_plot(
    fabrics_white,
    x_labels_white,
    tick_positions_white,
    energy_white,
    "Energy pada Jenis Kain Warna Putih di Setiap Channel RGB",
    output_path_white
)

# %%
# Fungsi reusable untuk membuat plot
def create_entropy_plot(fabrics, x_labels, tick_positions, entropy_data, title, output_path):
    plt.figure(figsize=(14, 6))
    plt.plot(tick_positions, entropy_data, label='Entropy', marker='x', markersize=8, color='cyan')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel('Average Values', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(tick_positions, x_labels, rotation=0, fontsize=10)

    # Tambahkan label jenis kain di tengah setiap grup RGB
    for i, fabric in enumerate(fabrics):
        plt.text(i * n_channels + 1, plt.ylim()[1] - 0.05, fabric, ha='center', va='top', fontsize=12, fontweight='bold')

    # Tambahkan garis pemisah antar jenis kain
    for i in range(1, len(fabrics)):
        plt.axvline(x=i * n_channels - 0.5, color='gray', linestyle='--', lw=1)

    plt.legend(loc='upper right', fontsize=10)
    plt.tight_layout()

    # Simpan plot ke dalam file
    plt.savefig(output_path, dpi=400)
    plt.show()


# Folder output
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"

# Plot untuk kain warna hitam
file_name_black = "entropy_jenis_kain_hitam.png"
output_path_black = os.path.join(output_folder, file_name_black)
create_entropy_plot(
    fabrics_black,
    x_labels_black,
    tick_positions_black,
    entropy_black,
    "Entropy pada Jenis Kain Warna Hitam di Setiap Channel RGB",
    output_path_black
)

# Plot untuk kain warna putih
file_name_white = "entropy_jenis_kain_putih.png"
output_path_white = os.path.join(output_folder, file_name_white)
create_entropy_plot(
    fabrics_white,
    x_labels_white,
    tick_positions_white,
    entropy_white,
    "Entropy pada Jenis Kain Warna Putih di Setiap Channel RGB",
    output_path_white
)

# %%
def create_asm_plot(fabrics, x_labels, tick_positions, asm_data, title, output_path):
    plt.figure(figsize=(14, 6))
    plt.plot(tick_positions, asm_data, label='ASM', marker='D', markersize=8, color='magenta')
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel('Average Values', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(tick_positions, x_labels, rotation=0, fontsize=10)

    # Tambahkan label jenis kain di tengah setiap grup RGB
    for i, fabric in enumerate(fabrics):
        plt.text(i * n_channels + 1, plt.ylim()[1] - 0.0005, fabric, ha='center', va='top', fontsize=12, fontweight='bold')

    # Tambahkan garis pemisah antar jenis kain
    for i in range(1, len(fabrics)):
        plt.axvline(x=i * n_channels - 0.5, color='gray', linestyle='--', lw=1)

    plt.legend(loc='upper right', fontsize=10)
    plt.tight_layout()

    # Simpan plot ke dalam file
    plt.savefig(output_path, dpi=400)
    plt.show()


# Folder output
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"

# Plot untuk kain warna hitam
file_name_black = "asm_jenis_kain_hitam.png"
output_path_black = os.path.join(output_folder, file_name_black)
create_asm_plot(
    fabrics_black,
    x_labels_black,
    tick_positions_black,
    asm_black,
    "ASM (Angular Second Moment) pada Jenis Kain Warna Hitam di Setiap Channel RGB",
    output_path_black
)

# Plot untuk kain warna putih
file_name_white = "asm_jenis_kain_putih.png"
output_path_white = os.path.join(output_folder, file_name_white)
create_asm_plot(
    fabrics_white,
    x_labels_white,
    tick_positions_white,
    asm_white,
    "ASM (Angular Second Moment) pada Jenis Kain Warna Putih di Setiap Channel RGB",
    output_path_white
)

# %%
# Daftar jenis kain dan channel warna
fabrics_black = ['Katun Hitam', 'Polyester Hitam']
fabrics_white = ['Katun Putih', 'Polyester Putih']
channels = ['Blue', 'Green', 'Red']
n_channels = len(channels)

# Label x-axis
x_labels_black = [f"{channel}" for _ in fabrics_black for channel in channels]
x_labels_white = [f"{channel}" for _ in fabrics_white for channel in channels]

# Posisi tick
tick_positions_black = np.arange(len(x_labels_black))
tick_positions_white = np.arange(len(x_labels_white))

# Ekstrak data dari std_df
contrast_blue = std_df.loc['contrast_B']
contrast_green = std_df.loc['contrast_G']
contrast_red = std_df.loc['contrast_R']

homogeneity_blue = std_df.loc['homogeneity_B']
homogeneity_green = std_df.loc['homogeneity_G']
homogeneity_red = std_df.loc['homogeneity_R']

disimilarity_blue = std_df.loc['dissimilarity_B']
disimilarity_green = std_df.loc['dissimilarity_G']
disimilarity_red = std_df.loc['dissimilarity_R']

energy_blue = std_df.loc['energy_B']
energy_green = std_df.loc['energy_G']
energy_red = std_df.loc['energy_R']

correlation_blue = std_df.loc['correlation_B']
correlation_green = std_df.loc['correlation_G']
correlation_red = std_df.loc['correlation_R']

entropy_blue = std_df.loc['entropy_B']
entropy_green = std_df.loc['entropy_G']
entropy_red = std_df.loc['entropy_R']

asm_blue = std_df.loc['asm_B']
asm_green = std_df.loc['asm_G']
asm_red = std_df.loc['asm_R']


# Filter data berdasarkan jenis kain (hitam dan putih)
contrast_black = [
    contrast_blue[0], contrast_green[0], contrast_red[0],  # Katun Hitam
    contrast_blue[2], contrast_green[2], contrast_red[2]   # Polyester Hitam
]
contrast_white = [
    contrast_blue[1], contrast_green[1], contrast_red[1],  # Katun Putih
    contrast_blue[3], contrast_green[3], contrast_red[3]   # Polyester Putih
]

homogeneity_black = [
    homogeneity_blue[0], homogeneity_green[0], homogeneity_red[0],
    homogeneity_blue[2], homogeneity_green[2], homogeneity_red[2]
]
homogeneity_white = [
    homogeneity_blue[1], homogeneity_green[1], homogeneity_red[1],
    homogeneity_blue[3], homogeneity_green[3], homogeneity_red[3]
]

disimilarity_black = [
    disimilarity_blue[0], disimilarity_green[0], disimilarity_red[0],
    disimilarity_blue[2], disimilarity_green[2], disimilarity_red[2]
]
disimilarity_white = [
    disimilarity_blue[1], disimilarity_green[1], disimilarity_red[1],
    disimilarity_blue[3], disimilarity_green[3], disimilarity_red[3]
]

energy_black = [
    energy_blue[0], energy_green[0], energy_red[0],
    energy_blue[2], energy_green[2], energy_red[2]
]
energy_white = [
    energy_blue[1], energy_green[1], energy_red[1],
    energy_blue[3], energy_green[3], energy_red[3]
]

correlation_black = [
    correlation_blue[0], correlation_green[0], correlation_red[0],
    correlation_blue[2], correlation_green[2], correlation_red[2]
]
correlation_white = [
    correlation_blue[1], correlation_green[1], correlation_red[1],
    correlation_blue[3], correlation_green[3], correlation_red[3]
]

entropy_black = [
    entropy_blue[0], entropy_green[0], entropy_red[0],
    entropy_blue[2], entropy_green[2], entropy_red[2]
]
entropy_white = [
    entropy_blue[1], entropy_green[1], entropy_red[1],
    entropy_blue[3], entropy_green[3], entropy_red[3]
]

asm_black = [
    asm_blue[0], asm_green[0], asm_red[0],
    asm_blue[2], asm_green[2], asm_red[2]
]
asm_white = [
    asm_blue[1], asm_green[1], asm_red[1],
    asm_blue[3], asm_green[3], asm_red[3]
]
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_4632\1555017103.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[0], contrast_green[0], contrast_red[0],  # Katun Hitam
# C:\Users\asus\AppData\Local\Temp\ipykernel_4632\1555017103.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   contrast_blue[2], contrast_green[2], contrast_red[2]   # Polyester Hitam
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# Daftar fitur dan warna
features = ['contrast', 'correlation', 'energy', 'homogeneity', 'dissimilarity', 'entropy', 'asm']
feature_labels = ['Contrast', 'Correlation', 'Energy', 'Homogeneity', 'Dissimilarity', 'Entropy', 'ASM']
colors = ['blue', 'green', 'red', 'yellow', 'purple', 'orange', 'cyan']

# Jenis kain dan channel warna
fabrics_list = {
    'hitam': ['Katun Hitam', 'Polyester Hitam'],
    'putih': ['Katun Putih', 'Polyester Putih']
}
channels = ['Blue', 'Green', 'Red']
n_channels = len(channels)

# Folder output
output_folder = r"D:\SEMESTER6\PengenalaPola\analisis_kain_glcm_rgb\outputs\glcm_plots_analysis"

# Loop untuk memproses jenis kain hitam dan putih
for fabric_type, fabrics in fabrics_list.items():
    # Buat label sumbu x: misalnya Katun Hitam - B, dst.
    x_labels = [f"{fabric} - {channel}" for fabric in fabrics for channel in channels]
    tick_positions = np.arange(len(x_labels))

    # Mulai membuat plot
    plt.figure(figsize=(14, 6))
    offset = 0.25  # Jarak antar bar dalam satu grup

    # Loop untuk setiap fitur dan plot bar
    for i, feature in enumerate(features):
        data_B = std_df.loc[f'{feature}_B'][[f for f in fabrics]]  # Ambil kolom sesuai jenis kain
        data_G = std_df.loc[f'{feature}_G'][[f for f in fabrics]]
        data_R = std_df.loc[f'{feature}_R'][[f for f in fabrics]]

        # Gabungkan data menjadi urutan sesuai x_labels
        combined_data = []
        for col in fabrics:
            combined_data.append(data_B[col])
            combined_data.append(data_G[col])
            combined_data.append(data_R[col])

        # Posisi bar dengan offset
        positions = [pos + (i - len(features) / 2) * offset for pos in tick_positions]

        plt.bar(positions, combined_data, width=0.2, label=feature_labels[i], color=colors[i])

    # Judul dan label
    plt.title(f'Standar Deviasi Fitur GLCM - Jenis Kain Warna {fabric_type.capitalize()} di Setiap Channel RGB',
              fontsize=14, fontweight='bold')
    plt.ylabel('Standard Deviation Values', fontsize=12)
    plt.grid(True, axis='y', linestyle='--', alpha=0.6)
    plt.xticks(tick_positions, x_labels, rotation=90, fontsize=10)

    # Tambahkan label jenis kain di tengah setiap grup RGB
    for i, fabric in enumerate(fabrics):
        plt.text(i * n_channels + 1, plt.ylim()[1] - 0.02, fabric, ha='center', va='top', fontsize=12, fontweight='bold')

    # Garis pemisah antar jenis kain
    for i in range(1, len(fabrics)):
        plt.axvline(x=i * n_channels - 0.5, color='gray', linestyle='--', lw=1)

    # Menggunakan log scale pada sumbu Y
    plt.yscale('log')  # Aktifkan log scale

    # Legenda dan layout
    plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1), fontsize=10)
    plt.tight_layout()

    # Simpan gambar
    file_name = f"std_deviation_barchart_all_features_jenis_kain_{fabric_type}.png"
    output_path = os.path.join(output_folder, file_name)
    plt.savefig(output_path, dpi=400)

    # Tampilkan plot
    plt.show()

# %% [markdown]
# ##**Perbedaan Kain Katun dan Polyester Berdasarkan Tekstur (GLCM)**
#
# ### 1. **Tekstur Katun Lebih Halus & Seragam**
# - Standar deviasi dari fitur seperti **Contrast**, **Homogeneity**, dan **Correlation** pada katun lebih kecil.
# - Artinya, **tekstur katun lebih seragam dan halus**, tidak banyak variasi dalam pola seratnya.
#
# ### 2. **Tekstur Polyester Lebih Kasar & Tidak Teratur**
# - Polyester memiliki **standar deviasi yang lebih tinggi**, terutama pada fitur **Entropy** dan **Dissimilarity**.
# - Ini menunjukkan bahwa **tekstur polyester lebih tidak teratur dan kompleks**, sehingga terlihat lebih "kasar" secara visual maupun saat dianalisis komputer.
#
# ### 3. **Katun: Lebih Stabil di Semua Channel Warna**
# - Nilai tekstur katun di channel **Red, Green, Blue** cenderung stabil dan tidak banyak berbeda.
# - Cocok untuk aplikasi yang membutuhkan **konsistensi warna dan tekstur**, seperti analisis citra otomatis.
#
# ### 4. **Polyester: Variasi Tinggi, Butuh Penanganan Khusus**
# - Polyester menunjukkan **perbedaan nilai yang lebih besar antar channel warna**.
# - Perlu **normalisasi tambahan** jika digunakan dalam sistem pengenalan pola atau klasifikasi otomatis.
#
# ---
#
# ## **Kesimpulan Singkat**
# > Katun memiliki **tekstur yang lebih seragam dan halus**, sedangkan Polyester memiliki **tekstur lebih kasar dan bervariasi**. Dalam analisis citra, **katun lebih mudah dianalisis**, sementara **polyester butuh pre-processing tambahan** agar hasilnya lebih akurat.
